# %%
import google.generativeai as genai
import PIL.Image
import cv2 as cv

# %%
API_KEY = 'AIzaSyA-kFuG9a2JuU6555g14nstSo5NTMSLDgM'
genai.configure(api_key=API_KEY)

# %%
model = genai.GenerativeModel('gemini-pro-vision')

# %%
#path_to_image = r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\licensed-image.jpg'
path_to_image = r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\2224298.jpg'

# %%
img = PIL.Image.open(path_to_image)
#img

# %%
# OpenCV will be used to capture an image from the webcam
cap = cv.VideoCapture(0) # video capture source camera (Here webcam of laptop) 
cap.set(3,640) #width=640
cap.set(4,480) #height=480
#ret,frame = cap.read() # return a single frame in variable `frame`

while(True):

    ret,frame = cap.read() # return a single frame in variable `frame`
    cv.imshow('img1',frame) #display the captured image
    
    if cv.waitKey(1) & 0xFF == ord('y'): #save on pressing 'y' 
        cv.imwrite(r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\c1.png',frame)
        cv.destroyAllWindows()
        break

cap.release()

path_to_saved_image = r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\c1.png'

image = PIL.Image.open(path_to_saved_image)
image
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=640x480>

# %%
response = model.generate_content(image)

# %%
print(response.text)
# Out:
#  The photo shows a man with dark curly hair and a beard. He is wearing a gray t-shirt and has his hand on his head. He has a serious expression on his face.

# %%
prompt = "Write a short, engaging blog post based on this picture. It should include a description of the beverages in the photo and talk about the count."
prompt_1 = "Can you tell whether the cups are empty or full?"
prompt_2 = 'Tell more about this person'

response = model.generate_content([prompt_2, image], stream=True)
response.resolve()
print(response.text)
# Out:
#  This person is a young man with dark curly hair, a beard and mustache, and brown eyes. He is wearing a gray t-shirt and has his hand on his head. He looks like he is stressed or upset.

# %%
# OpenCV will be used to capture an image from the webcam
cap = cv.VideoCapture(0) # video capture source camera (Here webcam of laptop) 
cap.set(3,640) #width=640
cap.set(4,480) #height=480
#ret,frame = cap.read() # return a single frame in variable `frame`

while(True):

    ret,frame = cap.read() # return a single frame in variable `frame`
    cv.imshow('img1',frame) #display the captured image
    
    if cv.waitKey(1) & 0xFF == ord('y'): #save on pressing 'y' 
        cv.imwrite(r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\c1.png',frame)
        cv.destroyAllWindows()
        break

cap.release()

path_to_saved_image = r'C:\Users\Namina Wijetunga\Documents\Zone24x7\Images\c1.png'

img = PIL.Image.open(path_to_saved_image)
img

# image = cv.imread(path_to_image)

# # show the image in a custom resolution
# cv.namedWindow('Original Image', cv.WINDOW_NORMAL)
# cv.resizeWindow('Original Image', 640,480)
# cv.imshow('Original Image', image)

# cv.waitKey(0) 
# cv.destroyAllWindows()
